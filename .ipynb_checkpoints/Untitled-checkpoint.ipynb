# %%
#Import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

# %%
# %load_ext autoreload
# %autoreload 2

# %%
group_number = 2
path_dir = Path.cwd() / 'data' / f'{group_number}'
# examine available files in your folder
list(path_dir.glob('*gz'))
# Out:
# [WindowsPath('C:/Users/User1/Documents/Y3/Boundary Layer/Assignment 2/ASSIGNMENT-2/data/2/US-MMS_clean.csv.gz'),
#  WindowsPath('C:/Users/User1/Documents/Y3/Boundary Layer/Assignment 2/ASSIGNMENT-2/data/2/US-MOz_clean.csv.gz')]

# %%
# specify the site name
name_of_site = 'US-MMS'

# %%
# load dataset
site_file = name_of_site + '_clean.csv.gz'
path_data = path_dir / site_file
df_data = pd.read_csv(path_data, index_col='time', parse_dates=['time'])
df_data.head()

#df_2009=df_data.loc['2009 01 01':'2009 12 31'] #for parameters
#df_jul=df_data.loc['2010 07 01':'2010 07 31'] #summer month for model
#df_dec=df_data.loc['2010 12 01': '2010 12 31'] #for winter month for model
# Out:
#                        WS  RH  TA    PA      WD    P  SWIN   LWIN  SWOUT  \
# time
# 1999-01-01 01:00:00  2.98 NaN NaN  99.0   95.50  0.0   0.0  190.0    0.0
# 1999-01-01 02:00:00  2.93 NaN NaN  99.0  108.71  0.0   0.0  188.0    0.0
# 1999-01-01 03:00:00  2.96 NaN NaN  99.0  122.46  0.0   0.0  187.5    0.0
# 1999-01-01 04:00:00  3.03 NaN NaN  99.1  118.99  0.0   0.0  187.6    0.0
# 1999-01-01 05:00:00  3.63 NaN NaN  99.2  124.80  0.0   0.0  186.4    0.0
#
#                      LWOUT  NETRAD       H     LE  USTAR  ZL
# time
# 1999-01-01 01:00:00  250.7   -60.7 -21.310 -0.350  0.344 NaN
# 1999-01-01 02:00:00  248.8   -60.8 -14.473 -0.321  0.247 NaN
# 1999-01-01 03:00:00  247.6   -60.1 -16.784 -0.786  0.255 NaN
# 1999-01-01 04:00:00  247.7   -60.1 -12.367 -0.191  0.227 NaN
# 1999-01-01 05:00:00  246.9   -60.5 -23.069 -0.650  0.350 NaN

# %%
df_fluxes = df_data.filter(['NETRAD', 'H', 'LE'])

# %%
df_fluxes
# Out:
#                      NETRAD           H          LE
# time
# 1999-01-01 01:00:00  -60.70  -21.310000   -0.350000
# 1999-01-01 02:00:00  -60.80  -14.473000   -0.321000
# 1999-01-01 03:00:00  -60.10  -16.784000   -0.786000
# 1999-01-01 04:00:00  -60.10  -12.367000   -0.191000
# 1999-01-01 05:00:00  -60.50  -23.069000   -0.650000
# 1999-01-01 06:00:00  -58.90  -16.367000   -0.297000
# 1999-01-01 07:00:00  -54.10   -7.244000   -0.284000
# 1999-01-01 08:00:00  -49.10   -1.776000   -0.026000
# 1999-01-01 09:00:00  -13.61    3.111000    3.419000
# 1999-01-01 10:00:00   88.83    6.949000    0.412000
# 1999-01-01 11:00:00   80.85   16.653000    1.324000
# 1999-01-01 12:00:00  129.16   38.427000    2.738000
# 1999-01-01 13:00:00  151.51   37.223000    3.543000
# 1999-01-01 14:00:00  157.54   47.103000    3.944000
# 1999-01-01 15:00:00  107.45   17.708000    6.232000
# 1999-01-01 16:00:00   73.29   31.807000    7.452000
# 1999-01-01 17:00:00   32.01    7.034000   -3.161000
df_2007DJF=df_fluxes.loc['2006 12 01':'2007 02 28']
df_2008DJF=df_fluxes.loc['2007 12 01':'2008 02 29']
df_2009DJF=df_fluxes.loc['2008 12 01':'2009 02 28']
df_2010DJF=df_fluxes.loc['2009 12 01':'2010 02 28']
df_2011DJF=df_fluxes.loc['2010 12 01':'2011 02 28']
df_2012DJF=df_fluxes.loc['2011 12 01':'2012 02 29']
df_2013DJF=df_fluxes.loc['2012 12 01':'2013 02 28']
df_2014DJF=df_fluxes.loc['2013 12 01':'2014 02 28']
df_2015DJF=df_fluxes.loc['2014 12 01':'2015 02 28']
df_2016DJF=df_fluxes.loc['2015 12 01':'2016 02 29']
df_2017DJF=df_fluxes.loc['2016 12 01':'2017 02 28']
df_2018DJF=df_fluxes.loc['2017 12 01':'2018 02 28']
df_2019DJF=df_fluxes.loc['2018 12 01':'2019 02 28']

# %%
len(df_2010DJF)
# Out:
# 2160

# %%
len(df_2011DJF)
# Out:
# 2160

# %%
QE2010=df_2010DJF.LE
QH2010=df_2010DJF.H
QSTAR2010=df_2010DJF.NETRAD

QE2011=df_2011DJF.LE
QH2011=df_2011DJF.H
QSTAR2011=df_2011DJF.NETRAD

# %%
QE2010.loc['2009 12 01']
# Out:
# time
# 2009-12-01 00:00:00    -5.355
# 2009-12-01 01:00:00    -3.674
# 2009-12-01 02:00:00    -5.124
# 2009-12-01 03:00:00    -3.487
# 2009-12-01 04:00:00    -2.113
# 2009-12-01 05:00:00    -2.150
# 2009-12-01 06:00:00    -3.097
# 2009-12-01 07:00:00    -3.663
# 2009-12-01 08:00:00    -4.328
# 2009-12-01 09:00:00    -2.577
# 2009-12-01 10:00:00    13.228
# 2009-12-01 11:00:00    28.703
# 2009-12-01 12:00:00    41.674
# 2009-12-01 13:00:00    68.372
# 2009-12-01 14:00:00    50.625
# 2009-12-01 15:00:00    54.816
# 2009-12-01 16:00:00    33.836
# 2009-12-01 17:00:00    27.203
# 2009-12-01 18:00:00     6.116
# 2009-12-01 19:00:00    -4.547
# 2009-12-01 20:00:00     4.516
# 2009-12-01 21:00:00    -2.038
# 2009-12-01 22:00:00     1.172
# 2009-12-01 23:00:00    -0.960
# Name: LE, dtype: float64

# %%
df_2010DJF.loc[:,['LE','NETRAD','H']].plot(figsize=(15,4))

# %%
df_2011DJF.loc[:].plot(figsize=(15,4))

# %%
df_2011DJF.describe()
# Out:
#             NETRAD            H           LE
# count  2160.000000  1939.000000  1940.000000
# mean     28.843851    20.067016     2.769180
# std     112.487726    61.029638    10.877841
# min    -107.505000  -243.748000  -100.471000
# 25%     -27.898000   -12.332500    -1.251250
# 50%      -5.892500    -0.077000     0.150500
# 75%      51.347250    34.751000     4.987250
# max     526.139000   462.369000   143.487000

# %%
df_2010DJF.describe()
# Out:
#             NETRAD            H           LE
# count  2160.000000  1921.000000  1945.000000
# mean     31.441333    23.692629     3.226793
# std     112.776940    64.698089    12.172542
# min    -100.535000  -191.280000   -75.536000
# 25%     -24.002000   -10.028000    -1.265000
# 50%      -3.394500     1.874000     0.166000
# 75%      54.563000    32.668000     5.372000
# max     547.527000   373.883000    85.844000

# %%
#2010
daily_range=[]
df_2010DJF.loc['2009 12 01'].plot()

# %%
a=np.max(df_2010DJF.loc['2009 12 01'])-np.min(df_2010DJF.loc['2009 12 01'])

# %%
QSTAR_2010_median=QSTAR2010.resample('1D').median()

# %%
QSTAR_2010_median=QSTAR2011.resample('1D').median()

# %%
QE_2011_median=QE2011.resample('1D').median()
QE_2010_median=QE2010.resample('1D').median()
QH_2011_median=QH2011.resample('1D').median()
QH_2010_median=QH2010.resample('1D').median()
QSTAR_2011_median=QSTAR2011.resample('1D').median()
QSTAR_2010_median=QSTAR2010.resample('1D').median()

QH_2011_range=QH2011.resample('1D').max()-QH2011.resample('1D').min()
QH_2010_range=QH2010.resample('1D').max()-QH2010.resample('1D').min()
QE_2011_range=QE2011.resample('1D').max()-QE2011.resample('1D').min()
QE_2010_range=QE2010.resample('1D').max()-QE2010.resample('1D').min()
QSTAR_2011_range=QSTAR2011.resample('1D').max()-QSTAR2011.resample('1D').min()
QSTAR_2010_range=QSTAR2010.resample('1D').max()-QSTAR2010.resample('1D').min()


#QH_2010_median=QH2010.resample('1D').median()

# %%
print(np.mean(QE_2011_median))
print(np.mean(QE_2010_median))
print(np.mean(QH_2011_median))
print(np.mean(QH_2010_median))
print(np.mean(QSTAR_2011_median))
print(np.mean(QSTAR_2010_median))
# Out:
# 0.2903426966292134
# 0.17384999999999998
# -0.01682022471910088
# 0.41618333333333324
# -16.497100000000003
# -16.99677777777777

# %%
np.median(QE2011.loc['2010 12 01'])
# Out:
# 0.9305000000000001

# %%
plt.plot(df_2010DJF.loc[:,['NETRAD']])

# %%
plt.plot(df_2010DJF.loc[:,['NETRAD']])
plt.plot(df_2011DJF.loc[:,['NETRAD']])

# %%
#X1=QSTAR2011.index.strftime('%j')
#X1=[int(x) for x in X1]
#X2=QSTAR2010.index.strftime('%j')
#X2=[int(x) for x in X2]
Y1=QSTAR2011
Y2=QSTAR2010
#X1=np.arange(0,91,0.0416666667)
#X1=[int(x) for x in X1]
X1=QSTAR2010.index.date
X2=QSTAR2010.index.date
print (X1)
#X2=np.arange(0,2160,1)
#len(X1)
X3=np.arange(0,2160,1)
# Out:
# [datetime.date(2009, 12, 1) datetime.date(2009, 12, 1)
#  datetime.date(2009, 12, 1) ... datetime.date(2010, 2, 28)
#  datetime.date(2010, 2, 28) datetime.date(2010, 2, 28)]

# %%
#plt.figure(figsize=(20,10))
#plt.plot(X1,Y1.values,'r',label='2010-11')
#plt.plot(X2,Y2.values,'b',label='2009-10')
#plt.legend()
#plt.ylabel('Net Rad')
#plt.xlabel('Date')
#plt.xlim(range(0,91))
#plt.xticks(('2009 12 01', '2009 12 15','2010 01 01','2010 01 15', '2010 02 01', '2010 02 15'), ['01 Dec','15 Dec' ,'01 Jan', '15 Jan', '01 Feb', '15 Feb'], rotation=20)

# %%
plt.figure(figsize=(30,10))
plt.plot(X3,QSTAR2011,'blue',label='2010-11 La Nina')
plt.plot(X3,QSTAR2010,'red',label='2009-10 El Nino', alpha=0.7)
plt.xticks((0, 360,720,1080, 1440, 1800), ['01 Dec','15 Dec' ,'01 Jan', '15 Jan', '01 Feb', '15 Feb'], rotation=20)
plt.xlabel('Time (Day-Month)')
plt.ylabel('$Q*$ ($W\ m^2$)')
plt.title('Observed Q* in DJF 2009-10 and 2010-11')
plt.legend()

# %%
plt.figure(figsize=(30,10))
plt.plot(X3,QE2011,'blue',label='2010-11 La Nina')
plt.plot(X3,QE2010,'red',label='2009-10 El Nino', alpha=0.7)
plt.xticks((0, 360,720,1080, 1440, 1800), ['01 Dec','15 Dec' ,'01 Jan', '15 Jan', '01 Feb', '15 Feb'], rotation=20)
plt.xlabel('Time (Day-Month)')
plt.ylabel('$Q_E$ ($W\ m^2$)')
plt.title('Observed $Q_E$ in DJF 2009-10 and 2010-11')
plt.legend()

# %%
plt.figure(figsize=(30,10))
plt.plot(X3,QH2011,'blue',label='2010-11 La Nina')
plt.plot(X3,QH2010,'red',label='2009-10 El Nino', alpha=0.7)
plt.xticks((0, 360,720,1080, 1440, 1800), ['01 Dec','15 Dec' ,'01 Jan', '15 Jan', '01 Feb', '15 Feb'], rotation=20)
plt.xlabel('Time (Day-Month)')
plt.ylabel('$Q_H$ ($W\ m^2$)')
plt.title('Observed $Q_H$ in DJF 2009-10 and 2010-11')
plt.legend()

# %%
#QE_2011_median
#QE_2010_median
#QH_2011_median
#QH_2010_median
X4=np.arange(0,90,1)

# %%
plt.figure(figsize=(30,10))
plt.plot(X4,QH_2011_median,'blue',label='2010-11 La Nina')
plt.plot(X4,QH_2010_median,'red',label='2009-10 El Nino', alpha=0.7)
#plt.xticks((0,31,62), ['01 Dec','01 Jan','01 Feb',], rotation=20)
plt.xlabel('Time (Day-Month)')
plt.ylabel('Median $Q_H$ ($W\ m^2$)')
plt.title('Observed $Q_H$ Daily Median in DJF 2009-10 and 2010-11')
plt.legend()

# %%
plt.figure(figsize=(30,10))
plt.plot(X4,QE_2011_median,'blue',label='2010-11 La Nina')
plt.plot(X4,QE_2010_median,'red',label='2009-10 El Nino', alpha=0.7)
#plt.xticks((0,31,62), ['01 Dec','01 Jan','01 Feb',], rotation=20)
plt.xlabel('Time (Day-Month)')
plt.ylabel('Median $Q_E$ ($W\ m^2$)')
plt.title('Observed $Q_E$ Daily Median in DJF 2009-10 and 2010-11')
plt.legend()

# %%
plt.figure(figsize=(30,10))
plt.plot(X4,QE_2011_range,'blue',label='2010-11 La Nina')
plt.plot(X4,QE_2010_range,'red',label='2009-10 El Nino', alpha=0.7)
#plt.xticks((0,31,62), ['01 Dec','01 Jan','01 Feb',], rotation=20)
plt.xlabel('Time (Day-Month)')
plt.ylabel('Range $Q_E$ ($W\ m^2$)')
plt.title('Observed $Q_E$ Daily Range in DJF 2009-10 and 2010-11')
plt.legend()

# %%
plt.figure(figsize=(30,10))
plt.plot(X4,QH_2011_range,'blue',label='2010-11 La Nina')
plt.plot(X4,QH_2010_range,'red',label='2009-10 El Nino', alpha=0.7)
#plt.xticks((0,31,62), ['01 Dec','01 Jan','01 Feb',], rotation=20)
plt.xlabel('Time (Day-Month)')
plt.ylabel('Range $Q_H$ ($W\ m^2$)')
plt.title('Observed $Q_H$ Daily Range in DJF 2009-10 and 2010-11')
plt.legend()

# %%
plt.figure(figsize=(30,10))
plt.plot(X4,QSTAR_2011_range,'blue',label='2010-11 La Nina')
plt.plot(X4,QSTAR_2010_range,'red',label='2009-10 El Nino', alpha=0.7)
#plt.xticks((0,31,62), ['01 Dec','01 Jan','01 Feb',], rotation=20)
plt.xlabel('Time (Day-Month)')
plt.ylabel('Range $Q*$ ($W\ m^2$)')
plt.title('Observed $Q*$ Daily Range in DJF 2009-10 and 2010-11')
plt.legend()

# %%
data=np.genfromtxt("Nino A2.csv", delimiter=',', filling_values=np.nan)
#year=np.genfromtxt("Nino A2.csv", delimiter=',', usecols=(0), dtype=None)
year=data[:,0]
SST=data[:,1]
#assign variables
x=year
y=SST

# %%
x[0]=1999

# %%
SST
# Out:
# array([-1.5, -1.7, -0.7, -0.1,  0.9,  0.4,  0.6, -0.8,  0.7, -1.6, -0.8,
#         1.5, -1.4, -0.8, -0.4, -0.4,  0.6,  2.5, -0.3, -0.9,  0.8])

# %%
x
# Out:
# array([1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006., 2007.,
#        2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016.,
#        2017., 2018., 2019.])
